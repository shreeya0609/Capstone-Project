# %% [markdown]
# # *Data Analysis for Simulation Data*
#
# ### *Code by - OM*

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sklearn

# Models
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score

# %%
# Read & merge the data 
def create_merged_dataset(path):
    files = os.listdir(path)
    timestamps = 0
    c = 1
    data = pd.DataFrame()
    for name in files:
        temp = pd.read_excel("Datasets/"+name)
        if(timestamps==0):
            data.insert(0,"Timestamps",temp.iloc[:,0])
            timestamps = 1
    
        data.insert(c,name[:len(name)-5],temp.iloc[:,1])
        c+=1
    data.set_index("Timestamps")
    data.to_csv("Simulated_dataset.csv")    
    
create_merged_dataset("Datasets")

# %% [markdown]
# ## *Data Analysis*

# %%
df = pd.read_csv("Datasets/Simulated_dataset.csv", index_col="Timestamps")
df.head()
# Out:
#             Unnamed: 0  Cell_Voltage       SOC  Drive_Cycle    Current  \
# Timestamps
# 0.0                  0      3.500000  1.000000          0.0   0.000000
# 0.5                  1      3.500000  1.000000          0.0   0.000000
# 1.0                  2      3.500000  1.000000          0.0 -15.947959
# 1.5                  3      3.460239  0.999877          0.0 -15.947959
# 2.0                  4      3.455171  0.999754          0.0 -15.947959
#
#             Temperature
# Timestamps
# 0.0          298.150000
# 0.5          298.149991
# 1.0          298.149983
# 1.5          298.150435
# 2.0          298.150893

# %%
# Statistics of dataset 
print("--------- Statistics of dataset: ---------")
print("Data entries: ",df.shape[0])
print("Features: ",df.shape[1])

print("\n\n--------- Datatypes: ---------")
pd.DataFrame(df.dtypes)
# Out:
# --------- Statistics of dataset: ---------
# Data entries:  1048575
# Features:  6
#
#
# --------- Datatypes: ---------
#                     0
# Unnamed: 0      int64
# Cell_Voltage  float64
# SOC           float64
# Drive_Cycle   float64
# Current       float64
# Temperature   float64

# %%
df.drop(labels=['Unnamed: 0'],axis=1,inplace=True)

# %%
# Find the missing values 
df.replace("?", np.nan, inplace=True)

missing_data = df.isnull()
print("---------Number of missing entries:--------- \n")
pd.DataFrame(df.shape[0]-missing_data.count(),columns=['Missing count'])
# Out:
# ---------Number of missing entries:---------
#               Missing count
# Cell_Voltage              0
# SOC                       0
# Drive_Cycle               0
# Current                   0
# Temperature               0

# %%
df.head()
# Out:
#             Cell_Voltage       SOC  Drive_Cycle    Current  Temperature
# Timestamps
# 0.0             3.500000  1.000000          0.0   0.000000   298.150000
# 0.5             3.500000  1.000000          0.0   0.000000   298.149991
# 1.0             3.500000  1.000000          0.0 -15.947959   298.149983
# 1.5             3.460239  0.999877          0.0 -15.947959   298.150435
# 2.0             3.455171  0.999754          0.0 -15.947959   298.150893

# %% [markdown]
# <h2 id="data_standardization">Data Standardization / Data Normalization</h2>
# <p>
# Data is usually collected from different agencies with different formats.
# (Data Standardization is also a term for a particular type of data normalization, where we subtract the mean and divide by the standard deviation)
# </p>
#
# <b>What is Standardization?</b>
# <p>Standardization is the process of transforming data into a common format which allows the researcher to make the meaningful comparison.
# </p>
#
# <b>Example</b>

# %% [markdown]
# <p>The formula for unit conversion is<p>
# L/100km = 235 / mpg
# <p>We can do many mathematical operations directly in Pandas.</p>

# %%
cols = df.columns

# Create new dataframe copy
data = df.copy(deep=True)

for col in cols:
    df[col] = df[col]/df[col].max()

df.head()
# Out:
#             Cell_Voltage       SOC  Drive_Cycle   Current  Temperature
# Timestamps
# 0.0             0.949642  1.000000          0.0  0.000000     0.308630
# 0.5             0.949642  1.000000          0.0  0.000000     0.308630
# 1.0             0.949642  1.000000          0.0 -0.629183     0.308630
# 1.5             0.938854  0.999877          0.0 -0.629183     0.308630
# 2.0             0.937479  0.999754          0.0 -0.629183     0.308631

# %% [markdown]
# ## *Split data - Train-Test Split & features and labels*

# %%
#  Split the data into features and labels

x = df[['Cell_Voltage', 'Current', 'Drive_Cycle','Temperature']]
y = df[['SOC']]
print("Data splitting complete.....")
# Out:
# Data splitting complete.....

# %%
x.head()
# Out:
#             Cell_Voltage   Current  Drive_Cycle  Temperature
# Timestamps
# 0.0             0.949642  0.000000          0.0     0.308630
# 0.5             0.949642  0.000000          0.0     0.308630
# 1.0             0.949642 -0.629183          0.0     0.308630
# 1.5             0.938854 -0.629183          0.0     0.308630
# 2.0             0.937479 -0.629183          0.0     0.308631

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,test_size=0.2, random_state=42)

# %% [markdown]
# ## *Model development & Testing*

# %%
rfregressor = RandomForestRegressor(random_state=42)

# %%
rfregressor.fit(train_x, train_y.values.ravel())
# Out:
# RandomForestRegressor(random_state=42)

# %%
preds = rfregressor.predict(test_x)

# %%
accuracy = (rfregressor.score(test_x, test_y))
print("\n------ Accuracy Score =",accuracy*100,"% ----------")
# Out:
# ------ Accuracy Score = 99.66676640764379 % ----------
